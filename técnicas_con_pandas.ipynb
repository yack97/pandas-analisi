# %% [markdown]
# <a href="https://colab.research.google.com/github/yack97/pandas-analisi/blob/main/te%CC%81cnicas_con_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://drive.google.com/file/d/1wWSjqRDtNi5rqmocJ3zNnulU-zBFKsSm/view?usp=share_link'

# %%
file_id = url.split('/')[-2]

# %%
read_url='https://drive.google.com/uc?id=' + file_id

# %%
df = pd.read_csv(read_url)

# %%
df. head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(len(df))
# Out:
# 891

# %%
print(df.shape)
# Out:
# (891, 12)

# %%
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['Age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df_copyAge = df.iloc[5]

# %%
print(df_copyAge)
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
del df_copyAge

# %%
df_copyAge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 df_copyAge
#
# NameError: name 'df_copyAge' is not defined

# %%
dfcopyAge = df['Age'].copy()

# %%
dfcopyAge
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
print(dfcopyAge.to_string())
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5        NaN
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17       NaN
# 18     31.00
# 19       NaN
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26       NaN
# 27     19.00
# 28       NaN
# 29       NaN
# 30     40.00
# 31       NaN
# 32       NaN
# 33     66.00
# 34     28.00
# 35     42.00
# 36       NaN
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42       NaN
# 43      3.00
# 44     19.00
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55       NaN
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64       NaN
# 65       NaN
# ...

# %%
print(df['Age'].mean())
# Out:
# 29.69911764705882

# %%
print(dfcopyAge.mode())
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
#se toma la desicion de remplazar los datos faltantes por el promedio entre el anterior y consecuente al faltate
# esta desicion es tomada en base al promedio de edades,
#la moda y pequeño estudio sobre el rango de edades de la epoca
dfcopyAge = dfcopyAge.fillna(dfcopyAge.mean())

# %%
print(dfcopyAge.to_string())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
# 30     40.000000
# 31     29.699118
# 32     29.699118
# 33     66.000000
# 34     28.000000
# 35     42.000000
# 36     29.699118
# 37     21.000000
# 38     18.000000
# 39     14.000000
# 40     40.000000
# 41     27.000000
# 42     29.699118
# 43      3.000000
# 44     19.000000
# 45     29.699118
# 46     29.699118
# 47     29.699118
# 48     29.699118
# 49     18.000000
# 50      7.000000
# 51     21.000000
# ...

# %%
print(dfcopyAge.dtypes)
# Out:
# float64

# %%
dfcopyAge = dfcopyAge.astype(int)

# %%
print(dfcopyAge.to_string())
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
# 5      29
# 6      54
# 7       2
# 8      27
# 9      14
# 10      4
# 11     58
# 12     20
# 13     39
# 14     14
# 15     55
# 16      2
# 17     29
# 18     31
# 19     29
# 20     35
# 21     34
# 22     15
# 23     28
# 24      8
# 25     38
# 26     29
# 27     19
# 28     29
# 29     29
# 30     40
# 31     29
# 32     29
# 33     66
# 34     28
# 35     42
# 36     29
# 37     21
# 38     18
# 39     14
# 40     40
# 41     27
# 42     29
# 43      3
# 44     19
# 45     29
# 46     29
# 47     29
# 48     29
# 49     18
# 50      7
# 51     21
# 52     49
# 53     29
# 54     65
# 55     29
# 56     21
# 57     28
# 58      5
# 59     11
# 60     22
# 61     38
# 62     45
# 63      4
# 64     29
# 65     29
# 66     29
# 67     19
# 68     17
# 69     26
# 70     32
# 71     16
# 72     21
# 73     26
# 74     32
# 75     25
# 76     29
# 77     29
# 78      0
# 79     30
# 80     22
# 81     29
# 82     29
# ...

# %%
dfcopyAge.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
dfcpA = dfcopyAge.value_counts().to_frame()
dfcpA.plot(kind='pie')

# %%
dfcpA = dfcopyAge.value_counts().to_frame(name='edades')

# %%
import matplotlib.pyplot as plt

# %%
dfcpA = dfcopyAge.value_counts().to_frame()

# %%
print(dfcpA.to_string())
# Out:
#     Age
# 29  197
# 24   31
# 22   27
# 28   27
# 30   27
# 18   26
# 19   25
# 21   24
# 36   23
# 25   23
# 32   20
# 35   18
# 26   18
# 27   18
# 31   17
# 16   17
# 34   16
# 20   16
# 23   16
# 40   15
# 33   15
# 45   14
# 39   14
# 42   13
# 17   13
# 38   11
# 2    10
# 4    10
# 50   10
# 47    9
# 44    9
# 48    9
# 54    8
# 9     8
# 51    7
# 1     7
# 0     7
# 14    7
# 37    6
# 3     6
# 41    6
# 52    6
# 49    6
# 43    5
# 58    5
# 15    5
# 8     4
# 5     4
# 62    4
# 56    4
# 60    4
# 11    4
# 65    3
# 46    3
# 7     3
# 55    3
# 70    3
# 6     3
# 61    3
# 64    2
# 57    2
# 13    2
# 71    2
# 10    2
# 63    2
# 59    2
# 66    1
# 53    1
# 80    1
# 12    1
# 74    1

# %%
print(dfcpA.columns)
# Out:
# Index(['Age'], dtype='object')

# %%
dfcpA = dfcpA.rename(columns={'Age': '', 'Cantidad': 'Edad'})

# %%
print(dfcpA.columns)
# Out:
# Index(['object'], dtype='object')

# %%
print(dfcpA.to_string())
# Out:
#     object
# 29     197
# 24      31
# 22      27
# 28      27
# 30      27
# 18      26
# 19      25
# 21      24
# 36      23
# 25      23
# 32      20
# 35      18
# 26      18
# 27      18
# 31      17
# 16      17
# 34      16
# 20      16
# 23      16
# 40      15
# 33      15
# 45      14
# 39      14
# 42      13
# 17      13
# 38      11
# 2       10
# 4       10
# 50      10
# 47       9
# 44       9
# 48       9
# 54       8
# 9        8
# 51       7
# 1        7
# 0        7
# 14       7
# 37       6
# 3        6
# 41       6
# 52       6
# 49       6
# 43       5
# 58       5
# 15       5
# 8        4
# 5        4
# 62       4
# 56       4
# 60       4
# 11       4
# 65       3
# 46       3
# 7        3
# 55       3
# 70       3
# 6        3
# 61       3
# 64       2
# 57       2
# 13       2
# 71       2
# 10       2
# 63       2
# 59       2
# 66       1
# 53       1
# 80       1
# 12       1
# 74       1

# %%
print(dfcpA.columns)
# Out:
# Index(['object'], dtype='object')

# %%
dfcpA = dfcpA.astype(int)

# %%
print(dfcpA.columns)
# Out:
# Index(['object'], dtype='object')

# %%
dfcpA = dfcpA.rename(columns={'': '', 'Cantidad': 'Edad'})

# %%
print(dfcpA.columns)
# Out:
# Index(['object'], dtype='object')

# %%
dfcpA.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dfcpA2 = dfcpA.reset_index()

# %%
dfcpA2.set_axis(['Age', 'Cantidad'], axis=1)
# Out:
#     Age  Cantidad
# 0    29       197
# 1    24        31
# 2    22        27
# 3    28        27
# 4    30        27
# ..  ...       ...
# 66   66         1
# 67   53         1
# 68   80         1
# 69   12         1
# 70   74         1
#
# [71 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.axes as axes

# %%
print(dfcpA2)
# Out:
#     index  object
# 0      29     197
# 1      24      31
# 2      22      27
# 3      28      27
# 4      30      27
# ..    ...     ...
# 66     66       1
# 67     53       1
# 68     80       1
# 69     12       1
# 70     74       1
#
# [71 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.axes as axes

fig, ax = plt.subplots()

plt.bar(dfcpA2['index'], dfcpA2['object'])

ax.set_ylim(0, 100)

plt.show()

# %%
print(dfcopyAge)
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    29
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
print(dfcopyAge.to_string())
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
# 5      29
# 6      54
# 7       2
# 8      27
# 9      14
# 10      4
# 11     58
# 12     20
# 13     39
# 14     14
# 15     55
# 16      2
# 17     29
# 18     31
# 19     29
# 20     35
# 21     34
# 22     15
# 23     28
# 24      8
# 25     38
# 26     29
# 27     19
# 28     29
# 29     29
# 30     40
# 31     29
# 32     29
# 33     66
# 34     28
# 35     42
# 36     29
# 37     21
# 38     18
# 39     14
# 40     40
# 41     27
# 42     29
# 43      3
# 44     19
# 45     29
# 46     29
# 47     29
# 48     29
# 49     18
# 50      7
# 51     21
# 52     49
# 53     29
# 54     65
# 55     29
# 56     21
# 57     28
# 58      5
# 59     11
# 60     22
# 61     38
# 62     45
# 63      4
# 64     29
# 65     29
# 66     29
# 67     19
# 68     17
# 69     26
# 70     32
# 71     16
# 72     21
# 73     26
# 74     32
# 75     25
# 76     29
# 77     29
# 78      0
# 79     30
# 80     22
# 81     29
# 82     29
# ...

# %%
df = df.assign(Age=dfcopyAge.index)

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male    0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    1      1
# 2                               Heikkinen, Miss. Laina  female    2      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    3      1
# 4                             Allen, Mr. William Henry    male    4      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df. head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male    0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    1      1
# 2                             Heikkinen, Miss. Laina  female    2      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    3      1
# 4                           Allen, Mr. William Henry    male    4      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_copyCabin = df.iloc[10]

# %%
print(df_copyCabin)
# Out:
# PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                         10
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# Name: 10, dtype: object

# %%
del df_copyCabin

# %%
df_copyCabin = df['Cabin'].copy()

# %%
print(df_copyCabin)
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
dfcpC = df_copyCabin.value_counts().to_frame()

# %%
print(dfcpC)
# Out:
#              Cabin
# B96 B98          4
# G6               4
# C23 C25 C27      4
# C22 C26          3
# F33              3
# ...            ...
# E34              1
# C7               1
# C54              1
# E36              1
# C148             1
#
# [147 rows x 1 columns]

# %%
print(dfcpC.to_string())
# Out:
#                  Cabin
# B96 B98              4
# G6                   4
# C23 C25 C27          4
# C22 C26              3
# F33                  3
# F2                   3
# E101                 3
# D                    3
# C78                  2
# C93                  2
# E8                   2
# D36                  2
# B77                  2
# C123                 2
# E121                 2
# E44                  2
# D35                  2
# C125                 2
# E67                  2
# B35                  2
# B18                  2
# E24                  2
# B49                  2
# C65                  2
# B20                  2
# B5                   2
# B57 B59 B63 B66      2
# C126                 2
# B51 B53 B55          2
# F4                   2
# C124                 2
# F G73                2
# B58 B60              2
# C52                  2
# D33                  2
# C68                  2
# D20                  2
# D26                  2
# B28                  2
# ...

# %%
df_copyCabin.isna().sum()
# Out:
# 687
